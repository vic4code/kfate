# %% [markdown]
# # Hetero-NN Quick Start: A Binary Classification Task

# %%
# !pipeline --help
# Out:
# Usage: pipeline [OPTIONS] COMMAND [ARGS]...
#
# Options:
#   --help  Show this message and exit.
#
# Commands:
#   config  pipeline config tool
#  - DESCRIPTION: Pipeline Config Command.

# %% [markdown]
# Assume we have a `FATE Flow Service` which name is `fateflow` and the port is `9380`, then exec

# %%
# !pipeline init --ip 172.31.14.182 --port 9380
# Out:
# Pipeline configuration succeeded.

# %% [markdown]
# In this tutorial, you will learn how to use Hetero-NN. It should be noted that Hetero-NN has also been upgraded to work similarly to Homo-NN, allowing for high customization of both models and datasets using the Pytorch backend. We will cover customization in a later chapter specifically for Hetero-NN.
#
# Additionally, Hetero-NN has also improved some interfaces, such as the Interactive-layer interface, which makes the logic of its usage clearer.
#
# In this chapter, we will provide an example of a basic binary classification task using Hetero-NN. The process of using this algorithm is consistent with other FATE algorithms: you will use the reader and transformer interfaces provided by FATE to input table data, and then input the data into the algorithm component. The component will then use the defined top/bottom model, optimizer, and loss function for training. The usage of this version is basically the same as the usage of the old version of FATE.
#
# If you want to understand the principle of the Hetero-NN algorithm, you can refer to doc/federated_component/hetero_nn.md.

# %% [markdown]
# ## Uploading Tabular Data
#
# At the very beginning, we upload data to FATE. We can directly upload data using the pipeline. Here we upload two files: breast_hetero_guest.csv for the guest, and breast_hetero_host.csv for the host. Please notice that in this tutorial we are using a standalone version, if you are using a cluster version, you need to upload corresponding data on each machine.

# %%
from pipeline.backend.pipeline import PipeLine  # pipeline class

# we have two party: guest, whose data with labels
#                    host, without label
# the dataset is vertically split

dense_data_guest = {"name": "breast_hetero_guest", "namespace": f"experiment"}
dense_data_host = {"name": "breast_hetero_host", "namespace": f"experiment"}

guest= 9999
host = 10000

pipeline_upload = PipeLine().set_initiator(role='guest', party_id=guest).set_roles(guest=guest, host=host)

partition = 4

# 上传一份数据
pipeline_upload.add_upload_data(file="/data/projects/fate/persistence/fate/examples/data/breast_hetero_guest.csv",
                                table_name=dense_data_guest["name"],             # table name
                                namespace=dense_data_guest["namespace"],         # namespace
                                head=1, partition=partition)               # data info

pipeline_upload.add_upload_data(file="/data/projects/fate/persistence/fate/examples/data/breast_hetero_host.csv",
                                table_name=dense_data_host["name"],
                                namespace=dense_data_host["namespace"],
                                head=1, partition=partition)      # data info

pipeline_upload.upload(drop=1)
# Out:
#  UPLOADING:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||100.00%
# 2023-02-21 02:06:42.648 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202302210206425080000
#
# 2023-02-21 02:06:42.656 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# 2023-02-21 02:06:43.668 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:01
# m2023-02-21 02:06:44.689 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-02-21 02:06:44.690 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:02
# 2023-02-21 02:06:45.711 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:03
# 2023-02-21 02:06:46.728 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:04
# 2023-02-21 02:06:47.745 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:05
# 2023-02-21 02:06:48.761 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:06
# 2023-02-21 02:06:49.778 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:07
# 2023-02-21 02:06:50.791 | ERROR    | __main__:<module>:28 - An error has been caught in function '<module>', process 'MainProcess' (2760), thread 'MainThread' (140063814596416):
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x7f6325c44df0, file "/usr/local/lib/python3.8/site-packages/ipykernel_launcher.py", line 1>
#            └ <function _run_code at 0x7f6325c55940>
#   File "/usr/local/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x7f6325c44df0, file "/usr/local/lib/python3.8/site-packages/ipykernel_launcher.py", line 1>
#   File "/usr/local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from '/usr/local/lib/python3.8/site-packages/ipykernel/kernelapp.py'>
#   File "/usr/local/lib/python3.8/site-packages/traitlets/config/application.py", line 1041, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x7f63217f51f0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f6325d63700>
#   File "/usr/local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 711, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x7f63235188b0>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f63217f4580>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f6325d63700>
#   File "/usr/local/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x7f6325449b80>
#     │    └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f63217f4580>
#   File "/usr/local/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x7f632544b700>
#     └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#   File "/usr/local/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x7f632548e4c0>
#     └ <Handle <TaskWakeupMethWrapper object at 0x7f625b438400>(<Future finis...e00>, ...],))>)>
#   File "/usr/local/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle <TaskWakeupMethWrapper object at 0x7f625b438400>(<Future finis...e00>, ...],))>)>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle <TaskWakeupMethWrapper object at 0x7f625b438400>(<Future finis...e00>, ...],))>)>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle <TaskWakeupMethWrapper object at 0x7f625b438400>(<Future finis...e00>, ...],))>)>
#   File "/usr/local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#           │    └ <function Kernel.process_one at 0x7f6322157160>
#           └ <ipykernel.ipkernel.IPythonKernel object at 0x7f63217ba730>
#   File "/usr/local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#           │         └ ([<zmq.sugar.frame.Frame object at 0x7f63259e8b40>, <zmq.sugar.frame.Frame object at 0x7f6320778eb0>, <zmq.sugar.frame.Frame ...
#           └ <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7f63217ba730>>
#   File "/usr/local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#           └ <coroutine object Kernel.execute_request at 0x7f625ada51c0>
#   File "/usr/local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#                           └ <coroutine object IPythonKernel.do_execute at 0x7f625ada5f40>
#   File "/usr/local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#           │     └ <function ZMQInteractiveShell.run_cell at 0x7f63217e4940>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f63217baca0>
#   File "/usr/local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 530, in run_cell
#     return super().run_cell(*args, **kwargs)
#                              │       └ {'store_history': True, 'silent': False, 'cell_id': None}
#                              └ ('from pipeline.backend.pipeline import PipeLine  # pipeline class\n\n# we have two party: guest, whose data with labels\n#  ...
#   File "/usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2945, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x7f6322be5700>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f63217baca0>
#   File "/usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3000, in _run_cell
#     return runner(coro)
#            │      └ <coroutine object InteractiveShell.run_cell_async at 0x7f625ada5440>
#            └ <function _pseudo_sync_runner at 0x7f6322bd8040>
#   File "/usr/local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#     │    └ <method 'send' of 'coroutine' objects>
#     └ <coroutine object InteractiveShell.run_cell_async at 0x7f625ada5440>
#   File "/usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3203, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                        │    │             │        │     └ '/tmp/ipykernel_2760/3596527615.py'
#                        │    │             │        └ [<_ast.ImportFrom object at 0x7f625b15ee50>, <_ast.Assign object at 0x7f632076b910>, <_ast.Assign object at 0x7f632076b1f0>, ...
#                        │    │             └ <_ast.Module object at 0x7f625b15e670>
#                        │    └ <function InteractiveShell.run_ast_nodes at 0x7f6322be59d0>
#                        └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f63217baca0>
#   File "/usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3382, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#              │    │        │     │              └ False
#              │    │        │     └ <ExecutionResult object at 7f625b35d9a0, execution_count=9 error_before_exec=None error_in_exec=None info=<ExecutionInfo obje...
#              │    │        └ <code object <module> at 0x7f625b0aec90, file "/tmp/ipykernel_2760/3596527615.py", line 28>
#              │    └ <function InteractiveShell.run_code at 0x7f6322be5a60>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f63217baca0>
#   File "/usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3442, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#          │         │    │               │    └ {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, ...
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f63217baca0>
#          │         │    └ <property object at 0x7f6322bd4d10>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f63217baca0>
#          └ <code object <module> at 0x7f625b0aec90, file "/tmp/ipykernel_2760/3596527615.py", line 28>
#
# > File "/tmp/ipykernel_2760/3596527615.py", line 28, in <module>
#     pipeline_upload.upload(drop=1)
#     │               └ <function PipeLine.upload at 0x7f625b67e790>
#     └ <pipeline.backend.pipeline.PipeLine object at 0x7f625b355a90>
#
#   File "/usr/local/lib/python3.8/site-packages/pipeline/backend/pipeline.py", line 666, in upload
#     self._job_invoker.monitor_job_status(self._train_job_id,
#     │    │            │                  │    └ '202302210206425080000'
#     │    │            │                  └ <pipeline.backend.pipeline.PipeLine object at 0x7f625b355a90>
#     │    │            └ <function JobInvoker.monitor_job_status at 0x7f625b670ca0>
#     │    └ <pipeline.utils.invoker.job_submitter.JobInvoker object at 0x7f625b355fd0>
#     └ <pipeline.backend.pipeline.PipeLine object at 0x7f625b355a90>
#   File "/usr/local/lib/python3.8/site-packages/pipeline/utils/invoker/job_submitter.py", line 94, in monitor_job_status
#     raise ValueError(f"Job is failed, please check out job {job_id} by fate board or fate_flow cli")
#
# ValueError: Job is failed, please check out job 202302210206425080000 by fate board or fate_flow cli
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 28
#      18 pipeline_upload.add_upload_data(file="/data/projects/fate/persistence/fate/examples/data/breast_hetero_guest.csv",
#      19                                 table_name=dense_data_guest["name"],             # table name
#      20                                 namespace=dense_data_guest["namespace"],         # namespace
#      21                                 head=1, partition=partition)               # data info
#      23 pipeline_upload.add_upload_data(file="/data/projects/fate/persistence/fate/examples/data/breast_hetero_host.csv",
#      24                                 table_name=dense_data_host["name"],
#      25                                 namespace=dense_data_host["namespace"],
#      26                                 head=1, partition=partition)      # data info
# ---> 28 pipeline_upload.upload(drop=1)
#
# File /usr/local/lib/python3.8/site-packages/loguru/_logger.py:1226, in Logger.catch.<locals>.Catcher.__call__.<locals>.catch_wrapper(*args, **kwargs)
#    1224 def catch_wrapper(*args, **kwargs):
#    1225     with catcher:
# -> 1226         return function(*args, **kwargs)
#    1227     return default
#
# File /usr/local/lib/python3.8/site-packages/pipeline/backend/pipeline.py:666, in PipeLine.upload(self, drop)
#     664 self._train_job_id, detail_info = self._job_invoker.upload_data(upload_conf, int(drop))
#     665 self._train_board_url = detail_info["board_url"]
# --> 666 self._job_invoker.monitor_job_status(self._train_job_id,
#     667                                      "local",
#     668                                      0)
#
# File /usr/local/lib/python3.8/site-packages/pipeline/utils/invoker/job_submitter.py:94, in JobInvoker.monitor_job_status(self, job_id, role, party_id, previous_status)
#      91     return StatusCode.SUCCESS
#      93 elif status == JobStatus.FAILED:
# ---> 94     raise ValueError(f"Job is failed, please check out job {job_id} by fate board or fate_flow cli")
#      96 elif status == JobStatus.WAITING:
#      97     elapse_seconds = timedelta(seconds=int(time.time() - start_time))
#
# ValueError: Job is failed, please check out job 202302210206425080000 by fate board or fate_flow cli

# %% [markdown]
# The breast dataset is a binary dataset set with 30 features, and it is vertically split:
# guest holds 10 fetureas and label, while host holds 20 features

# %%
import pandas as pd
df = pd.read_csv('../../../../examples/data/breast_hetero_guest.csv')
df
# Out:
#       id  y        x0        x1        x2        x3        x4        x5  \
# 0    133  1  0.254879 -1.046633  0.209656  0.074214 -0.441366 -0.377645
# 1    273  1 -1.142928 -0.781198 -1.166747 -0.923578  0.628230 -1.021418
# 2    175  1 -1.451067 -1.406518 -1.456564 -1.092337 -0.708765 -1.168557
# 3    551  1 -0.879933  0.420589 -0.877527 -0.780484 -1.037534 -0.483880
# 4    199  0  0.426758  0.723479  0.316885  0.287273  1.000835  0.962702
# ..   ... ..       ...       ...       ...       ...       ...       ...
# 564  529  1 -0.583805 -1.613330 -0.605880 -0.581312  0.864944 -0.579301
# 565   40  0 -0.070240  0.744648 -0.141817 -0.162929 -1.006849 -0.317847
# 566  115  1 -0.538247  0.076989 -0.587413 -0.523125  0.772888 -0.091382
# 567    2  0  1.511870 -0.023974  1.347475  1.456285  0.527407  1.082932
# 568   39  0 -0.153073  0.055819  0.001155 -0.246430  1.255083  1.070209
#
#            x6        x7        x8        x9
# 0   -0.485934  0.347072 -0.287570 -0.733474
# 1   -1.111867 -0.959523 -0.096672 -0.121683
# 2   -1.305831 -1.745063 -0.499499 -0.302893
# 3   -0.555498 -0.768581  0.433960 -0.200928
# 4    1.077099  1.053586  2.996525  0.961696
# ..        ...       ...       ...       ...
# 564 -0.527672 -0.619360 -0.193738 -0.189844
# 565 -0.305547 -0.051865  0.150849 -0.691912
# 566 -0.584763 -0.641591 -0.748637  0.081139
# 567  0.854974  1.955000  1.152255  0.201391
# 568  1.107324  1.693103 -0.151676  1.283108
#
# [569 rows x 12 columns]

# %%
import pandas as pd
df = pd.read_csv('../../../../examples/data/breast_hetero_host.csv')
df
# Out:
#       id        x0        x1        x2        x3        x4        x5  \
# 0    133  0.449512 -1.247226  0.413178  0.303781 -0.123848 -0.184227
# 1    273 -1.245485 -0.842317 -1.255026 -1.038066 -0.426301 -1.088781
# 2    175 -1.549664 -1.126219 -1.546652 -1.216392 -0.354424 -1.167051
# 3    551 -0.851273  0.733108 -0.843535 -0.786363 -0.049836 -0.424532
# 4    199  0.091654  0.216499  0.103839 -0.034667  0.167930  0.308132
# ..   ...       ...       ...       ...       ...       ...       ...
# 564  529 -0.584300 -1.361252 -0.582390 -0.596377  0.970677 -0.270077
# 565   40 -0.195201  0.532980 -0.238451 -0.261342 -1.048999 -0.834452
# 566  115 -0.624062  0.521345 -0.635937 -0.615148  0.093918 -0.489914
# 567    2  1.579888  0.456187  1.566503  1.558884  0.942210  1.052926
# 568   39 -0.183840  0.356123 -0.147009 -0.272150  0.372887  0.400995
#
#            x6        x7        x8  ...       x10       x11       x12  \
# 0   -0.219076  0.268537  0.015996  ... -0.337360 -0.728193 -0.442587
# 1   -0.976392 -0.898898  0.983496  ... -0.493639  0.348620 -0.552483
# 2   -1.114873 -1.261820 -0.327193  ... -0.666881 -0.779358 -0.708418
# 3   -0.509221 -0.679649  0.797298  ... -0.451772  0.453852 -0.431696
# 4    0.366614  0.280661  0.505223  ... -0.707304 -1.026834 -0.702973
# ..        ...       ...       ...  ...       ...       ...       ...
# 564 -0.640169 -0.540104 -0.564504  ... -0.555357 -1.293361 -0.570305
# 565 -0.724413 -0.737944 -0.100834  ... -0.601554 -0.708235 -0.640599
# 566 -0.697043 -0.743876 -0.451325  ... -0.336999 -0.533695 -0.428726
# 567  1.363478  2.037231  0.939685  ...  1.228676 -0.780083  0.850928
# 568  0.219721  0.141115 -0.334494  ... -0.693589 -1.134788 -0.653965
#
#           x13       x14       x15       x16       x17       x18       x19
# 0   -0.272757 -0.608018 -0.577235 -0.501126  0.143371 -0.466431 -0.554102
# 1   -0.526877  2.253098 -0.827620 -0.780739 -0.376997 -0.310239  0.176301
# 2   -0.637545  0.710369 -0.976454 -1.057501 -1.913447  0.795207 -0.149751
# 3   -0.494754 -1.182041  0.281228  0.084759 -0.252420  1.038575  0.351054
# 4   -0.460212 -0.999033 -0.531406 -0.394360 -0.728830 -0.644416 -0.688003
# ..        ...       ...       ...       ...       ...       ...       ...
# 564 -0.479573  0.095344 -0.779555 -0.461337 -0.618041 -0.111671 -0.590414
# 565 -0.435790 -1.253710 -0.808059 -0.596618 -0.797283 -0.816347 -0.948996
# 566 -0.342062  0.254017 -0.022811 -0.449069 -0.662649 -0.939848  0.023110
# 567  1.181336 -0.297005  0.814974  0.213076  1.424827  0.237036  0.293559
# 568 -0.480013 -0.558016 -0.172595 -0.046543  0.133639 -0.819980 -0.229940
#
# [569 rows x 21 columns]

# %% [markdown]
# ## Write the Pipeline script and execute it
#
# After the upload is complete, we can start writing the pipeline script to submit a FATE task.

# %%
import torch as t
from torch import nn
from pipeline.backend.pipeline import PipeLine  # pipeline Class
from pipeline import fate_torch_hook
from pipeline.component import HeteroNN, Reader, DataTransform, Intersection  # Hetero NN Component, Data IO component, PSI component
from pipeline.interface import Data, Model # data, model for defining the work flow

# %% [markdown]
# ### fate_torch_hook
#
# Please be sure to execute the following fate_torch_hook function, which can modify some classes of torch, so that the torch layers, sequential, optimizer, and loss function you define in the scripts can be parsed and submitted by the pipeline.

# %%
from pipeline import fate_torch_hook
t = fate_torch_hook(t)

# %%
guest = 9999
host = 10000
pipeline = PipeLine().set_initiator(role='guest', party_id=guest).set_roles(guest=guest, host=host)

guest_train_data = {"name": "breast_hetero_guest", "namespace": "experiment"}
host_train_data = {"name": "breast_hetero_host", "namespace": "experiment"}

pipeline = PipeLine().set_initiator(role='guest', party_id=guest).set_roles(guest=guest, host=host)

# read uploaded dataset
reader_0 = Reader(name="reader_0")
reader_0.get_party_instance(role='guest', party_id=guest).component_param(table=guest_train_data)
reader_0.get_party_instance(role='host', party_id=host).component_param(table=host_train_data)
# The transform component converts the uploaded data to the DATE standard format
data_transform_0 = DataTransform(name="data_transform_0")
data_transform_0.get_party_instance(role='guest', party_id=guest).component_param(with_label=True)
data_transform_0.get_party_instance(role='host', party_id=host).component_param(with_label=False)
# intersection
intersection_0 = Intersection(name="intersection_0")

# %% [markdown]
# ### The Hetero NN Component
#
# Here we initialize the Hetero-NN component. We use get_party_instance to obtain the guest component and host component respectively.  As the model architectures of the two parties differ, we must specify the model parameters for each party using the respective components.

# %%
hetero_nn_0 = HeteroNN(name="hetero_nn_0", epochs=2,
                       interactive_layer_lr=0.01, batch_size=-1, validation_freqs=1, task_type='classification', seed=114514)
guest_nn_0 = hetero_nn_0.get_party_instance(role='guest', party_id=guest)
host_nn_0 = hetero_nn_0.get_party_instance(role='host', party_id=host)

# %% [markdown]
# ### Defining Guest & Host Model

# %%
# Guest Bottom, Top Model
guest_bottom = t.nn.Sequential(
    nn.Linear(10, 2),
    nn.ReLU()
)
guest_top = t.nn.Sequential(
    nn.Linear(2, 1),
    nn.Sigmoid()
)

# Host Bottom Model
host_bottom = t.nn.Sequential(
    nn.Linear(20, 2),
    nn.ReLU()
)

# After using fate_torch_hook, nn module can use InteractiveLayer, you can view the structure of Interactive layer with print
interactive_layer = t.nn.InteractiveLayer(out_dim=2, guest_dim=2, host_dim=2, host_num=1)
print(interactive_layer)

guest_nn_0.add_top_model(guest_top)
guest_nn_0.add_bottom_model(guest_bottom)
host_nn_0.add_bottom_model(host_bottom)

optimizer = t.optim.Adam(lr=0.01) # Notice! After fate_torch_hook, the optimizer can be initialized without model parameter
loss = t.nn.BCELoss()

hetero_nn_0.set_interactive_layer(interactive_layer)
hetero_nn_0.compile(optimizer=optimizer, loss=loss)
# Out:
# InteractiveLayer(
#   (activation): ReLU()
#   (guest_model): Linear(in_features=2, out_features=2, bias=True)
#   (host_model): ModuleList(
#     (0): Linear(in_features=2, out_features=2, bias=True)
#   )
#   (act_seq): Sequential(
#     (0): ReLU()
#   )
# )

# %%
pipeline.add_component(reader_0)
pipeline.add_component(data_transform_0, data=Data(data=reader_0.output.data))
pipeline.add_component(intersection_0, data=Data(data=data_transform_0.output.data))
pipeline.add_component(hetero_nn_0, data=Data(train_data=intersection_0.output.data))
pipeline.compile()

# %%
pipeline.fit()
# Out:
# 2023-02-20 08:53:43.232 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202302200853425897750
#
# 2023-02-20 08:53:43.244 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# m2023-02-20 08:53:44.264 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-02-20 08:53:44.265 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:01
# 2023-02-20 08:53:45.282 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:02
# 2023-02-20 08:53:46.300 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:03
# 2023-02-20 08:53:47.316 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:04
# 2023-02-20 08:53:48.332 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:05
# 2023-02-20 08:53:49.349 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:06
# 2023-02-20 08:53:51.381 | ERROR    | __main__:<module>:1 - An error has been caught in function '<module>', process 'MainProcess' (1766), thread 'MainThread' (139795747899200):
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x7f24bbbf1df0, file "/usr/local/lib/python3.8/site-packages/ipykernel_launcher.py", line 1>
#            └ <function _run_code at 0x7f24bbc02940>
#   File "/usr/local/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x7f24bbbf1df0, file "/usr/local/lib/python3.8/site-packages/ipykernel_launcher.py", line 1>
#   File "/usr/local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from '/usr/local/lib/python3.8/site-packages/ipykernel/kernelapp.py'>
#   File "/usr/local/lib/python3.8/site-packages/traitlets/config/application.py", line 1041, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x7f24b77a21f0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f24bbd10700>
#   File "/usr/local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 711, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x7f24b94c68b0>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f24b77a1610>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f24bbd10700>
#   File "/usr/local/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x7f24bb3f7b80>
#     │    └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f24b77a1610>
#   File "/usr/local/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x7f24bb3f9700>
#     └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#   File "/usr/local/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x7f24bb43a4c0>
#     └ <Handle <TaskWakeupMethWrapper object at 0x7f241251c490>(<Future finis...eb0>, ...],))>)>
#   File "/usr/local/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle <TaskWakeupMethWrapper object at 0x7f241251c490>(<Future finis...eb0>, ...],))>)>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle <TaskWakeupMethWrapper object at 0x7f241251c490>(<Future finis...eb0>, ...],))>)>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle <TaskWakeupMethWrapper object at 0x7f241251c490>(<Future finis...eb0>, ...],))>)>
#   File "/usr/local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#           │    └ <function Kernel.process_one at 0x7f24b8104160>
#           └ <ipykernel.ipkernel.IPythonKernel object at 0x7f24b7767760>
#   File "/usr/local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#           │         └ ([<zmq.sugar.frame.Frame object at 0x7f23f0da05c0>, <zmq.sugar.frame.Frame object at 0x7f24b77a90f0>, <zmq.sugar.frame.Frame ...
#           └ <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7f24b7767760>>
#   File "/usr/local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#           └ <coroutine object Kernel.execute_request at 0x7f24b778bc40>
#   File "/usr/local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#                           └ <coroutine object IPythonKernel.do_execute at 0x7f24125145c0>
#   File "/usr/local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#           │     └ <function ZMQInteractiveShell.run_cell at 0x7f24b7791940>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f24b7767cd0>
#   File "/usr/local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 530, in run_cell
#     return super().run_cell(*args, **kwargs)
#                              │       └ {'store_history': True, 'silent': False, 'cell_id': None}
#                              └ ('pipeline.fit()',)
#   File "/usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2945, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x7f24b8b92700>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f24b7767cd0>
#   File "/usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3000, in _run_cell
#     return runner(coro)
#            │      └ <coroutine object InteractiveShell.run_cell_async at 0x7f23f0dee6c0>
#            └ <function _pseudo_sync_runner at 0x7f24b8b85040>
#   File "/usr/local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#     │    └ <method 'send' of 'coroutine' objects>
#     └ <coroutine object InteractiveShell.run_cell_async at 0x7f23f0dee6c0>
#   File "/usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3203, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                        │    │             │        │     └ '/tmp/ipykernel_1766/1909854420.py'
#                        │    │             │        └ [<_ast.Expr object at 0x7f2412539bb0>]
#                        │    │             └ <_ast.Module object at 0x7f2412539670>
#                        │    └ <function InteractiveShell.run_ast_nodes at 0x7f24b8b929d0>
#                        └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f24b7767cd0>
#   File "/usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3382, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#              │    │        │     │              └ False
#              │    │        │     └ <ExecutionResult object at 7f2412539ca0, execution_count=14 error_before_exec=None error_in_exec=None info=<ExecutionInfo obj...
#              │    │        └ <code object <module> at 0x7f24124e12f0, file "/tmp/ipykernel_1766/1909854420.py", line 1>
#              │    └ <function InteractiveShell.run_code at 0x7f24b8b92a60>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f24b7767cd0>
#   File "/usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3442, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#          │         │    │               │    └ {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, ...
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f24b7767cd0>
#          │         │    └ <property object at 0x7f24b8b78c20>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f24b7767cd0>
#          └ <code object <module> at 0x7f24124e12f0, file "/tmp/ipykernel_1766/1909854420.py", line 1>
#
# > File "/tmp/ipykernel_1766/1909854420.py", line 1, in <module>
#     pipeline.fit()
#     │        └ <function PipeLine.fit at 0x7f23f1627a60>
#     └ <pipeline.backend.pipeline.PipeLine object at 0x7f2412539c10>
#
#   File "/usr/local/lib/python3.8/site-packages/pipeline/backend/pipeline.py", line 585, in fit
#     self._fit_status = self._job_invoker.monitor_job_status(self._train_job_id,
#     │    │             │    │            │                  │    └ '202302200853425897750'
#     │    │             │    │            │                  └ <pipeline.backend.pipeline.PipeLine object at 0x7f2412539c10>
#     │    │             │    │            └ <function JobInvoker.monitor_job_status at 0x7f23f1619d30>
#     │    │             │    └ <pipeline.utils.invoker.job_submitter.JobInvoker object at 0x7f2412539d30>
#     │    │             └ <pipeline.backend.pipeline.PipeLine object at 0x7f2412539c10>
#     │    └ None
#     └ <pipeline.backend.pipeline.PipeLine object at 0x7f2412539c10>
#   File "/usr/local/lib/python3.8/site-packages/pipeline/utils/invoker/job_submitter.py", line 94, in monitor_job_status
#     raise ValueError(f"Job is failed, please check out job {job_id} by fate board or fate_flow cli")
#
# ValueError: Job is failed, please check out job 202302200853425897750 by fate board or fate_flow cli
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 pipeline.fit()
#
# File /usr/local/lib/python3.8/site-packages/loguru/_logger.py:1226, in Logger.catch.<locals>.Catcher.__call__.<locals>.catch_wrapper(*args, **kwargs)
#    1224 def catch_wrapper(*args, **kwargs):
#    1225     with catcher:
# -> 1226         return function(*args, **kwargs)
#    1227     return default
#
# File /usr/local/lib/python3.8/site-packages/pipeline/backend/pipeline.py:585, in PipeLine.fit(self, job_parameters, callback_func)
#     581 self._train_board_url = detail_info["board_url"]
#     582 self._model_info = SimpleNamespace(model_id=detail_info["model_info"]["model_id"],
#     583                                    model_version=detail_info["model_info"]["model_version"])
# --> 585 self._fit_status = self._job_invoker.monitor_job_status(self._train_job_id,
#     586                                                         self._initiator.role,
#     587                                                         self._initiator.party_id)
#
# File /usr/local/lib/python3.8/site-packages/pipeline/utils/invoker/job_submitter.py:94, in JobInvoker.monitor_job_status(self, job_id, role, party_id, previous_status)
#      91     return StatusCode.SUCCESS
#      93 elif status == JobStatus.FAILED:
# ---> 94     raise ValueError(f"Job is failed, please check out job {job_id} by fate board or fate_flow cli")
#      96 elif status == JobStatus.WAITING:
#      97     elapse_seconds = timedelta(seconds=int(time.time() - start_time))
#
# ValueError: Job is failed, please check out job 202302200853425897750 by fate board or fate_flow cli

# %% [markdown]
# ## Get Component Output

# %%
# get predict scores
pipeline.get_component('hetero_nn_0').get_output_data()
# Out:
#       id label predict_result        predict_score  \
# 0      0   0.0              0  0.13979218900203705
# 1      1   0.0              0  0.19935783743858337
# 2      2   0.0              0   0.2489972561597824
# 3      3   0.0              0  0.25491416454315186
# 4      4   1.0              0   0.2584167718887329
# ..   ...   ...            ...                  ...
# 564  564   0.0              0  0.19034752249717712
# 565  565   1.0              0    0.261306494474411
# 566  566   1.0              0  0.26077690720558167
# 567  567   1.0              0   0.2625167667865753
# 568  568   0.0              0  0.24826040863990784
#
#                                         predict_detail   type
# 0    {'0': 0.860207810997963, '1': 0.13979218900203...  train
# 1    {'0': 0.8006421625614166, '1': 0.1993578374385...  train
# 2    {'0': 0.7510027438402176, '1': 0.2489972561597...  train
# 3    {'0': 0.7450858354568481, '1': 0.2549141645431...  train
# 4    {'0': 0.7415832281112671, '1': 0.2584167718887...  train
# ..                                                 ...    ...
# 564  {'0': 0.8096524775028229, '1': 0.1903475224971...  train
# 565   {'0': 0.738693505525589, '1': 0.261306494474411}  train
# 566  {'0': 0.7392230927944183, '1': 0.2607769072055...  train
# 567  {'0': 0.7374832332134247, '1': 0.2625167667865...  train
# 568  {'0': 0.7517395913600922, '1': 0.2482604086399...  train
#
# [569 rows x 6 columns]

# %%
# get summary
pipeline.get_component('hetero_nn_0').get_summary()
# Out:
# {'best_iteration': -1,
#  'history_loss': [0.9929580092430115, 0.9658427238464355],
#  'is_converged': False,
#  'validation_metrics': {'train': {'auc': [0.8850615717985308,
#     0.9316368056656624],
#    'ks': [0.6326568363194334, 0.7479123724961683]}}}

# %% [markdown]
# So far, we have gained a basic understanding of Hetero-NN and have utilized it to perform basic modeling tasks. Hetero-NN also supports the use of more complex models, datasets. For further information, refer to the additional tutorials provided.
